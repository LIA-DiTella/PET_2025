# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from torch import nn
from torchvision.models.video import mvit_v1_b, mvit_v2_s

# %%
model_mvit_v1_b = mvit_v1_b()
model_mvit_v1_b
# Out:
# MViT(
#   (conv_proj): Conv3d(3, 96, kernel_size=(3, 7, 7), stride=(2, 4, 4), padding=(1, 3, 3))
#   (pos_encoding): PositionalEncoding()
#   (blocks): ModuleList(
#     (0): MultiscaleBlock(
#       (norm1): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#       (norm2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#       (attn): MultiscaleAttention(
#         (qkv): Linear(in_features=96, out_features=288, bias=True)
#         (project): Sequential(
#           (0): Linear(in_features=96, out_features=96, bias=True)
#         )
#         (pool_k): Pool(
#           (pool): Conv3d(96, 96, kernel_size=(3, 3, 3), stride=(1, 8, 8), padding=(1, 1, 1), groups=96, bias=False)
#           (norm_act): Sequential(
#             (0): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#         )
#         (pool_v): Pool(
#           (pool): Conv3d(96, 96, kernel_size=(3, 3, 3), stride=(1, 8, 8), padding=(1, 1, 1), groups=96, bias=False)
# ...

# %%
model_mvit_v1_b.head[1].in_features
# Out:
# 768

# %%
model_mvit_v2_s = mvit_v2_s()

# %%
model_mvit_v2_s.head[1].in_features
# Out:
# 768

# %%
def set_dropout(model, dropout_rate):
    """Configura la tasa de dropout en el modelo.

    Args:
        model: Modelo PyTorch
        dropout_rate (float): Tasa de dropout a aplicar

    """
    for module in model.modules():
        if isinstance(module, nn.Dropout):
            module.p = dropout_rate

# %%
set_dropout(model_mvit_v1_b, 0.5)
set_dropout(model_mvit_v2_s, 0.5)

# %%
def set_parameter_requires_grad(model, feature_extract) -> None:
    """Configura requires_grad=False para los parámetros si feature_extract=True.

    Args:
        model: Modelo PyTorch
        feature_extract: Si es True, congela todos los parámetros excepto los últimos

    """
    if feature_extract:
        for name, param in model.named_parameters():
            param.requires_grad = name.startswith("head")

# %%
set_parameter_requires_grad(model_mvit_v1_b, True)
set_parameter_requires_grad(model_mvit_v2_s, True)

# %%
import os
import sys

sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))

# %%
import torch

# %%
from models.inceptionv3.inceptionv3_2d import get_inceptionv3_2d
from models.inceptionv3.inceptionv3_3d import get_inceptionv3_3d
from models.resnet18.resnet18_2d import get_resnet18_2d
from models.resnet18.resnet18_3d import get_resnet18_3d
from models.vit.vit_2d import get_vit_2d
from models.vit.vit_3d import get_vit_3d


rn282d = get_resnet18_2d({})
rn283d = get_resnet18_3d({})
vit2d = get_vit_2d({})
vit3d = get_vit_3d({})
inceptionv3_2d = get_inceptionv3_2d({})
inceptionv3_3d = get_inceptionv3_3d({})
# Out:
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /Users/nacho/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [01:14<00:00, 4.66MB/s]
#
# /Users/nacho/opt/anaconda3/envs/pet/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/nacho/opt/anaconda3/envs/pet/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
model_iv3_3d = get_inceptionv3_3d({})
model_iv3_3d
# Out:
# Cargando pesos preentrenados desde: /Users/nacho/Desktop/code/PET_2025/models/inceptionv3/../../external/pytorch-i3d/models/rgb_imagenet.pt
# Pesos preentrenados cargados exitosamente
# InceptionV3_3D(
#   (model): InceptionI3d(
#     (avg_pool): AvgPool3d(kernel_size=[2, 7, 7], stride=(1, 1, 1), padding=0)
#     (dropout): Dropout(p=0.5, inplace=False)
#     (logits): Unit3D(
#       (conv3d): Conv3d(1024, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#     )
#     (Conv3d_1a_7x7): Unit3D(
#       (conv3d): Conv3d(3, 64, kernel_size=(7, 7, 7), stride=(2, 2, 2), bias=False)
#       (bn): BatchNorm3d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (MaxPool3d_2a_3x3): MaxPool3dSamePadding(kernel_size=[1, 3, 3], stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#     (Conv3d_2b_1x1): Unit3D(
#       (conv3d): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
# ...

# %%
# empty = torch.randn(1, 3, 16, 224, 224)
empty = torch.randn(1, 3, 224, 224, 16)

# %%
model_iv3_3d(torch.randn(1, 3, 16, 224, 224))
# Out:
# tensor([[0.5232, 0.4768]], grad_fn=<SqueezeBackward1>)

# %%
model_iv3_3d(torch.randn(1, 3, 224, 224, 16))
# Out:
# tensor([[0.5755, 0.4245]], grad_fn=<SqueezeBackward1>)

# %%
iv3_3d_output = model_iv3_3d(empty)
iv3_3d_output.shape # torch.Size([1, 2, 1])

iv3_3d_output = iv3_3d_output.squeeze(2)
iv3_3d_output.shape # torch.Size([1, 2])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 iv3_3d_output = model_iv3_3d(empty)
#       2 iv3_3d_output.shape # torch.Size([1, 2, 1])
#       4 iv3_3d_output = iv3_3d_output.squeeze(2)
#
# File ~/opt/anaconda3/envs/pet/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/pet/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
# ...

# %%
model_rn18_3d = get_resnet18_3d({})
model_rn18_3d(empty).shape
# Out:
# torch.Size([1, 2])

# %%
model_vit_3d = get_vit_3d({})
model_vit_3d(empty).shape
# Out:
# torch.Size([1, 2])

# %%
# Probar InceptionV3_3D con formato I3D correcto: (BatchSize, 3, 16, 224, 224)
empty_i3d_format = torch.randn(1, 3, 16, 224, 224)
print("Entrada I3D format:", empty_i3d_format.shape)

iv3_3d_output = model_iv3_3d(empty_i3d_format)
print("Salida InceptionV3_3D:", iv3_3d_output.shape)

# %%
# Probar también con el formato que usan otros modelos: (BatchSize, 3, 224, 224, 16)
empty_other_format = torch.randn(1, 3, 224, 224, 16)
print("Entrada formato otros modelos:", empty_other_format.shape)

iv3_3d_output_other = model_iv3_3d(empty_other_format)
print("Salida InceptionV3_3D (convertido):", iv3_3d_output_other.shape)
# Out:
# Entrada formato otros modelos: torch.Size([1, 3, 224, 224, 16])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 5
#       2 empty_other_format = torch.randn(1, 3, 224, 224, 16)
#       3 print("Entrada formato otros modelos:", empty_other_format.shape)
# ----> 5 iv3_3d_output_other = model_iv3_3d(empty_other_format)
#       6 print("Salida InceptionV3_3D (convertido):", iv3_3d_output_other.shape)
#
# File ~/opt/anaconda3/envs/pet/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/pet/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
# ...

# %%
# Recargar el modelo con las mejoras
model_iv3_3d = get_inceptionv3_3d({})

print("=== Probando formato I3D (BatchSize, 3, 16, 224, 224) ===")
empty_i3d_format = torch.randn(1, 3, 16, 224, 224)
iv3_3d_output = model_iv3_3d(empty_i3d_format)
print("Salida:", iv3_3d_output.shape)
print()

print("=== Probando formato otros modelos (BatchSize, 3, 224, 224, 16) ===")
empty_other_format = torch.randn(1, 3, 224, 224, 16)
iv3_3d_output_other = model_iv3_3d(empty_other_format)
print("Salida:", iv3_3d_output_other.shape)
# Out:
# Cargando pesos preentrenados desde: /Users/nacho/Desktop/code/PET_2025/models/inceptionv3/../../external/pytorch-i3d/models/rgb_imagenet.pt
# Pesos preentrenados cargados exitosamente
# === Probando formato I3D (BatchSize, 3, 16, 224, 224) ===
# Dimensiones de entrada: torch.Size([1, 3, 16, 224, 224])
# Dimensiones finales antes de I3D: torch.Size([1, 3, 16, 224, 224])
# Salida: torch.Size([1, 2])
#
# === Probando formato otros modelos (BatchSize, 3, 224, 224, 16) ===
# Dimensiones de entrada: torch.Size([1, 3, 224, 224, 16])
# Redimensionamiento espacial aplicado: (224, 16) -> (224, 224)
# Dimensiones finales antes de I3D: torch.Size([1, 3, 224, 224, 224])
# Salida: torch.Size([2, 27])
